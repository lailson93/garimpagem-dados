# %% [markdown]
# Exercícios
#
# 1 - Aplique os algoritmos K-means [1] e AgglomerativeClustering [2] em qualquer dataset que você desejar (recomendação: iris). Compare os resultados utilizando métricas de avaliação de clusteres (completeness e homogeneity, por exemplo) [3].
#
#     [1] http://scikit-learn.org/stable/modules/clustering.html#k-means
#
#     [2] http://scikit-learn.org/0.17/modules/clustering.html#hierarchical-clustering
#
#     [3] http://scikit-learn.org/stable/modules/clustering.html#clustering-evaluation
#
# 2 - Qual o valor de K (número de clusteres) você escolheu para a questão anterior? Desenvolva o Método do Cotovelo (não utilizar lib!) e descubra o K mais adequado. Após descobrir, aplique novamente o K-means com o K adequado.
#
#     Ajuda: atributos do k-means
#
# 3 - Após a questão 2, você aplicou o algoritmo com K apropriado. Refaça o cálculo das métricas de acordo com os resultados de clusters obtidos com a questão anterior e verifique se o resultado melhorou.

# %%
from sklearn.datasets import load_iris
from sklearn import decomposition
from sklearn import metrics
from sklearn.model_selection import train_test_split
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
dataset = load_iris()
X = dataset.data
y = dataset.target

# %%
kmeans = KMeans(n_clusters=2, random_state=0).fit(X)

# %%
# kmeans.labels_

# %%
predictions= kmeans.predict(X)
data = decomposition.PCA(n_components=2).fit_transform(X)
data_df = pd.DataFrame(data)

# %%
# print(predictions)
# print(reduced)
# print(reduced_data_df)
data_df[2]=predictions
print(data_df)
# Out:
#             0         1  2
# 0   -2.684207  0.326607  0
# 1   -2.715391 -0.169557  0
# 2   -2.889820 -0.137346  0
# 3   -2.746437 -0.311124  0
# 4   -2.728593  0.333925  0
# 5   -2.279897  0.747783  0
# 6   -2.820891 -0.082105  0
# 7   -2.626482  0.170405  0
# 8   -2.887959 -0.570798  0
# 9   -2.673845 -0.106692  0
# 10  -2.506527  0.651935  0
# 11  -2.613143  0.021521  0
# 12  -2.787434 -0.227740  0
# 13  -3.225200 -0.503280  0
# 14  -2.643543  1.186195  0
# 15  -2.383869  1.344754  0
# 16  -2.622526  0.818090  0
# 17  -2.648323  0.319137  0
# 18  -2.199078  0.879244  0
# 19  -2.587346  0.520474  0
# 20  -2.310532  0.397868  0
# 21  -2.543235  0.440032  0
# 22  -3.215858  0.141616  0
# 23  -2.303129  0.105523  0
# 24  -2.356171 -0.031210  0
# 25  -2.507917 -0.139056  0
# 26  -2.469056  0.137887  0
# 27  -2.562391  0.374685  0
# 28  -2.639821  0.319290  0
# 29  -2.632848 -0.190076  0
# ..        ...       ... ..
# 120  2.428167  0.376782  1
# 121  1.198097 -0.605579  1
# 122  3.499265  0.456773  1
# 123  1.387668 -0.204031  1
# 124  2.275854  0.333387  1
# 125  2.614194  0.558367  1
# 126  1.257625 -0.179137  1
# 127  1.290670 -0.116425  1
# 128  2.122854 -0.210855  1
# 129  2.387564  0.462519  1
# 130  2.840961  0.372743  1
# 131  3.232343  1.370524  1
# 132  2.158738 -0.218326  1
# 133  1.443103 -0.143801  1
# 134  1.779640 -0.501465  1
# 135  3.076522  0.685764  1
# 136  2.144987  0.138907  1
# 137  1.904863  0.048048  1
# 138  1.168853 -0.164502  1
# 139  2.107654  0.371482  1
# 140  2.314303  0.182609  1
# 141  1.922451  0.409271  1
# 142  1.414072 -0.574925  1
# 143  2.563323  0.275975  1
# 144  2.419391  0.303504  1
# 145  1.944017  0.187415  1
# 146  1.525664 -0.375021  1
# 147  1.764046  0.078519  1
# 148  1.901629  0.115877  1
# 149  1.389666 -0.282887  1
#
# [150 rows x 3 columns]

# %%
colors = map(lambda x: colmap[x+1], predictions)

f, ax = plt.subplots()
ax.scatter(data_df[0], data_df[1], c=reduced_data_df[2], alpha=0.5, edgecolor='k')
plt.show()

f, ax = plt.subplots()
ax.scatter(reduced_data_df[0], reduced_data_df[1], c=y, alpha=0.5, edgecolor='k')
plt.show()

# %% [markdown]
# AgglomerativeClustering

# %%
from sklearn.cluster import AgglomerativeClustering

agglo_euclidean = AgglomerativeClustering(n_clusters=3, affinity="euclidean", linkage="complete").fit_predict(X)
agglo_manhattan = AgglomerativeClustering(n_clusters=3, affinity="manhattan", linkage="complete").fit_predict(X)

# Usando metodo euclidean

f, ax = plt.subplots()
ax.scatter(data_df[0], data_df[1], c=agglo_euclidean, alpha=0.5, edgecolor='k')
plt.show()

f, ax = plt.subplots()
ax.scatter(data_df[0], data_df[1], c=y, alpha=0.5, edgecolor='k')
plt.show()

# %%
# usando metodo manhattan
f, ax = plt.subplots()
ax.scatter(data_df[0], data_df[1], c=agglo_manhattan, alpha=0.5, edgecolor='k')
plt.show()

f, ax = plt.subplots()
ax.scatter(data_df[0], data_df[1], c=y, alpha=0.5, edgecolor='k')
plt.show()
